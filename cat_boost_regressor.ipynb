# %%
import pandas as pd
from datetime import datetime
from catboost import CatBoostRegressor
import matplotlib.pyplot as plt
import mplcursors
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import GridSearchCV

# %%
categorical_columns = ['vehicle_make', 'vehicle_model', 'city', 'car_variant', 'vehicle_fuel_type']
columns_to_be_dropped = ['month_of_vehicle_manufacture', 'year_of_vehicle_manufacture', 'registered_color',
                         'accidental_vehicle', 'Odometer_Reading_Present']

# return integer month, from string, default is 6
def month_to_number(month):
    if pd.isna(month):
        return 6
    try:
        # Try to convert directly to an integer
        month_number = int(month)
        if 1 <= month_number <= 12:
            return month_number
    except ValueError:
        # If month is a string, convert it to lower case and map to month number
        month = month.lower()
        month_dict = {
            'january': 1, 'february': 2, 'march': 3,
            'april': 4, 'may': 5, 'june': 6,
            'july': 7, 'august': 8, 'september': 9,
            'october': 10, 'november': 11, 'december': 12
        }
        return month_dict.get(month, 6)  # Return 6 if month is not recognized
    return 6

# Function to calculate count of months since manufacting data(year, month)
def calculate_months_since_manufactured(row, current_year, current_month):
    year, month = row['year_of_vehicle_manufacture'], row['month_of_vehicle_manufacture']
    return (current_year - year) * 12 + (current_month - month)
    
# Fuction to mark columns as category type
def convert_columns_as_category(columns, data):
    for column in columns:
        data[column] = data[column].astype('category')

# Convert values to uppercase
def convert_values_to_uppercase(columns, data):
    for column in columns:
        data[column] = data[column].str.strip()
        data[column] = data[column].str.upper()

# Replace text which is matching with a pattern
def replace_text(pattern, data, column):
    data[column] = data[column].str.replace(pattern, '', regex=True)

# Prune data
def prune_data(data):
    # set month number, considering string, int, nan cases 
    data['month_of_vehicle_manufacture'] = data['month_of_vehicle_manufacture'].apply(month_to_number)
    # add months_since_manufactured column
    data['months_since_manufactured'] = data.apply(calculate_months_since_manufactured, axis=1, current_year=datetime.now().year, current_month=datetime.now().month)
    # remove redundant features
    data = data.drop(columns=columns_to_be_dropped, axis=1)
    # convert values to uppercase
    convert_values_to_uppercase(categorical_columns, data)
    # remove yyyy-yyyy or yyyy from vehicle_model
    pattern = r'\b\d{4}-\d{4}\b|\b\d{4}\b'
    replace_text(pattern, data, 'vehicle_model')
    # mark columns as category type
    convert_columns_as_category(categorical_columns, data)
    return data

def plot_errors(x_axis, test_errors, train_errors):
    # Activate interactive plot in separate window
    # %matplotlib qt
    # Create a figure and axis
    fig, ax = plt.subplots()
    # Plot the data
    ax.plot(x_axis, test_errors, label='Test Errors', marker='o')
    ax.plot(x_axis, train_errors, label='Train Errors', marker='o')
    # Add labels and title
    ax.set_xlabel('X Axis')
    ax.set_ylabel('Error')
    ax.set_title('Zoomable Graph with Test and Train Errors')
    # Enable interactive cursor for zooming
    mplcursors.cursor(hover=True)
    # Add legend
    plt.legend()
    # Display the plot
    plt.show()

def plot_feature_importance(model, columns):
    feature_importances = model.feature_importances_  
    # Create a DataFrame for better visualization
    importance_df = pd.DataFrame({
        'Feature': columns,
        'Importance': feature_importances
    })
    # Sort the DataFrame by importance
    importance_df = importance_df.sort_values(by='Importance', ascending=False)
    # Visualize the feature importances
    plt.figure(figsize=(10, 6))
    plt.barh(importance_df['Feature'], importance_df['Importance'], color='skyblue')
    plt.xlabel('Importance')
    plt.title('Feature Importances')
    plt.gca().invert_yaxis()
    plt.show()
    
def train_model(df, model):
    train_data = df.sample(frac = 0.9)
    test_data = df.drop(train_data.index)
    train_inputs = train_data.drop(columns=['car_valuation'], axis=1)
    train_output = train_data['car_valuation']
    print(train_inputs.sample())
    test_inputs = test_data.drop(columns=['car_valuation'], axis=1)
    test_output = test_data['car_valuation']
    model.fit(train_inputs, train_output, cat_features=categorical_columns)
    # mean absolute error on train data
    train_prediction = model.predict(train_inputs)
    train_error = mean_absolute_error(train_prediction, train_output)
    # mean absolute error on test data
    test_predicted_output = model.predict(test_inputs)
    test_error = mean_absolute_error(test_predicted_output, test_output)
    print("test_error= ",test_error," train_error= ", train_error)
    # Plot Feature Importance
    # plot_feature_importance(model, train_inputs.columns)
    return test_error, train_error

# Training
def prune_data_and_train_model(data, model):
    data = prune_data(data)
    data = data.drop(columns=['id'], axis=1)
    train_model(data, model)

# %%
# return ids and predicted outcome using model
def run_model(data, model):
    ids = data['id']
    data = data.drop(columns=['id'], axis=1)
    predicted_output = model.predict(data)
    return ids, predicted_output

# predict outcomes and save in file
def predict_output_and_save(ids_original_order, data, model):
    ids, car_valuations = run_model(data, model)
    car_valuations = car_valuations.astype(int)
    df = pd.DataFrame({
        'id': ids,
        'car_valuation': car_valuations
    })
    df.to_csv('/Users/vikash.yadav/Documents/data_science_hackathon/car_valuation_data.csv', index=False)

def predict_output(data, model):
    ids = data['id']
    data = prune_data(data)
    data.to_csv('/Users/vikash.yadav/Documents/data_science_hackathon/pruned_data.csv', index=False)
    print(data.columns)
    predict_output_and_save(ids, data, model)

# %%
test_data = pd.read_csv('/Users/vikash.yadav/Documents/data_science_hackathon/test.csv')

# %%
model = CatBoostRegressor(iterations=1000, learning_rate=0.1, depth=6, loss_function='MAE', verbose=1000)
data = pd.read_csv('/Users/vikash.yadav/Documents/data_science_hackathon/train.csv')
data = prune_data(data)
# Out:
#     car_variant  odometer_reading vehicle_fuel_type  registered_color  \
# 418     LXI CNG               NaN            PETROL               NaN
#
#     vehicle_make vehicle_model    city  months_since_manufactured
# 418       MARUTI      ALTO 800  RAJKOT                         76
# 0:	learn: 238751.1080868	total: 1.39ms	remaining: 1.25s
# 899:	learn: 33574.9887649	total: 1.05s	remaining: 0us
# test_error=  109546.77018461093  train_error=  113936.70285164623
# Index(['id', 'car_variant', 'odometer_reading', 'vehicle_fuel_type',
#        'registered_color', 'vehicle_make', 'vehicle_model', 'city',
#        'months_since_manufactured'],
#       dtype='object')

# %%
param_grid = {
    'iterations': [1000, 3000],
    'learning_rate': [0.01, 0.05, 0.1, 0.5],
    'depth': [4, 6, 10],
    'border_count': [128, 254, 500],
    'subsample': [1],
    'verbose': [500]
}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=2, scoring='neg_mean_absolute_error', verbose=2)
data = pd.read_csv('/Users/vikash.yadav/Documents/data_science_hackathon/train.csv')
prune_data_and_train_model(data, grid_search)
predict_output(test_data, model)
# Out:
#     odometer_reading vehicle_make vehicle_model       city  \
# 93           61144.0       MARUTI      ALTO 800  GHAZIABAD
#
#     months_since_manufactured
# 93                         85
# Fitting 2 folds for each of 72 candidates, totalling 144 fits
# 0:	learn: 234978.8394776	total: 2.1ms	remaining: 2.1s
# 500:	learn: 157124.5272607	total: 217ms	remaining: 217ms
# 999:	learn: 137893.1514548	total: 452ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 236546.1766470	total: 583us	remaining: 583ms
# 500:	learn: 166494.2341105	total: 217ms	remaining: 216ms
# 999:	learn: 145909.9697688	total: 429ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 233312.2959866	total: 682us	remaining: 682ms
# 500:	learn: 114873.2182228	total: 202ms	remaining: 201ms
# 999:	learn: 93720.3646973	total: 432ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 234637.4229725	total: 1.25ms	remaining: 1.25s
# 500:	learn: 117233.2299357	total: 199ms	remaining: 199ms
# 999:	learn: 98192.9445397	total: 335ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 231380.4388812	total: 518us	remaining: 518ms
# 500:	learn: 92404.2860678	total: 179ms	remaining: 178ms
# 999:	learn: 74176.1894607	total: 363ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 232269.0583364	total: 611us	remaining: 611ms
# 500:	learn: 97242.9582151	total: 221ms	remaining: 220ms
# 999:	learn: 83295.4978004	total: 428ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 220679.0176981	total: 1.35ms	remaining: 1.34s
# 500:	learn: 41332.4626334	total: 210ms	remaining: 209ms
# 999:	learn: 27401.9665006	total: 444ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 215614.2123884	total: 540us	remaining: 540ms
# 500:	learn: 50364.9707505	total: 233ms	remaining: 232ms
# 999:	learn: 36494.0894365	total: 369ms	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 234978.8394776	total: 672us	remaining: 2.02s
# 500:	learn: 157124.5272607	total: 150ms	remaining: 746ms
# 1000:	learn: 137840.8003465	total: 275ms	remaining: 550ms
# 1500:	learn: 124242.9348438	total: 457ms	remaining: 456ms
# 2000:	learn: 116862.5726263	total: 671ms	remaining: 335ms
# 2500:	learn: 111052.3898957	total: 897ms	remaining: 179ms
# 2999:	learn: 105957.2123392	total: 1.05s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 236546.1766470	total: 506us	remaining: 1.52s
# 500:	learn: 166494.2341105	total: 217ms	remaining: 1.08s
# 1000:	learn: 145902.5571403	total: 424ms	remaining: 847ms
# 1500:	learn: 130625.7322288	total: 621ms	remaining: 620ms
# 2000:	learn: 121649.6639848	total: 813ms	remaining: 406ms
# 2500:	learn: 115650.7785030	total: 1s	remaining: 200ms
# 2999:	learn: 111128.8630258	total: 1.16s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 233312.2959866	total: 601us	remaining: 1.8s
# 500:	learn: 114873.2182228	total: 229ms	remaining: 1.14s
# 1000:	learn: 93713.6818331	total: 444ms	remaining: 887ms
# 1500:	learn: 80979.3099269	total: 625ms	remaining: 624ms
# 2000:	learn: 72792.1031779	total: 841ms	remaining: 420ms
# 2500:	learn: 64613.4870900	total: 1.09s	remaining: 218ms
# 2999:	learn: 60245.3827120	total: 1.28s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 234637.4229725	total: 1.25ms	remaining: 3.76s
# 500:	learn: 117233.2299357	total: 175ms	remaining: 875ms
# 1000:	learn: 98191.3506606	total: 375ms	remaining: 750ms
# 1500:	learn: 89881.7580305	total: 575ms	remaining: 574ms
# 2000:	learn: 83218.7129673	total: 726ms	remaining: 363ms
# 2500:	learn: 78995.2546158	total: 921ms	remaining: 184ms
# 2999:	learn: 74174.8021036	total: 1.13s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 231380.4388812	total: 594us	remaining: 1.78s
# 500:	learn: 92404.2860678	total: 147ms	remaining: 732ms
# 1000:	learn: 74174.3383300	total: 334ms	remaining: 666ms
# 1500:	learn: 60678.6108746	total: 466ms	remaining: 466ms
# 2000:	learn: 53683.6215550	total: 648ms	remaining: 324ms
# 2500:	learn: 48373.9657421	total: 884ms	remaining: 176ms
# 2999:	learn: 45010.3738479	total: 1.12s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 232269.0583364	total: 1.2ms	remaining: 3.6s
# 500:	learn: 97242.9582151	total: 220ms	remaining: 1.09s
# 1000:	learn: 83259.3473096	total: 449ms	remaining: 897ms
# 1500:	learn: 77403.3666354	total: 677ms	remaining: 676ms
# 2000:	learn: 70045.9984412	total: 904ms	remaining: 451ms
# 2500:	learn: 61643.0554880	total: 1.12s	remaining: 223ms
# 2999:	learn: 56937.9859293	total: 1.35s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 220679.0176981	total: 571us	remaining: 1.71s
# 500:	learn: 41332.4626334	total: 232ms	remaining: 1.16s
# 1000:	learn: 27401.3787891	total: 431ms	remaining: 860ms
# 1500:	learn: 21731.2522112	total: 632ms	remaining: 631ms
# 2000:	learn: 16507.5961797	total: 785ms	remaining: 392ms
# 2500:	learn: 14510.1633902	total: 939ms	remaining: 187ms
# 2999:	learn: 12706.4768002	total: 1.07s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.1s
# 0:	learn: 215614.2123884	total: 1.1ms	remaining: 3.29s
# 500:	learn: 50364.9707505	total: 164ms	remaining: 817ms
# 1000:	learn: 36493.3621169	total: 343ms	remaining: 685ms
# 1500:	learn: 28740.7554390	total: 544ms	remaining: 544ms
# 2000:	learn: 23872.1805467	total: 715ms	remaining: 357ms
# 2500:	learn: 20164.1731101	total: 945ms	remaining: 189ms
# 2999:	learn: 17688.7146142	total: 1.17s	remaining: 0us
# [CV] END border_count=128, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 234727.0516516	total: 1.44ms	remaining: 1.44s
# 500:	learn: 129229.1893855	total: 330ms	remaining: 328ms
# 999:	learn: 103832.6718301	total: 663ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 236367.5121378	total: 2.44ms	remaining: 2.43s
# 500:	learn: 139075.2827231	total: 332ms	remaining: 330ms
# 999:	learn: 104254.9704203	total: 679ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 232046.8439766	total: 853us	remaining: 853ms
# 500:	learn: 62270.6257137	total: 348ms	remaining: 346ms
# 999:	learn: 42949.6251237	total: 716ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 233739.9853485	total: 1.76ms	remaining: 1.76s
# 500:	learn: 67317.9864261	total: 362ms	remaining: 361ms
# 999:	learn: 42681.8781537	total: 739ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 228874.2171645	total: 757us	remaining: 757ms
# 500:	learn: 33800.5466128	total: 381ms	remaining: 379ms
# 999:	learn: 21349.3709987	total: 773ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 230474.1830885	total: 824us	remaining: 824ms
# 500:	learn: 43711.1189738	total: 376ms	remaining: 375ms
# 999:	learn: 23800.1561853	total: 769ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 210494.5331848	total: 736us	remaining: 735ms
# 500:	learn: 4883.9365470	total: 373ms	remaining: 372ms
# 999:	learn: 1977.9293449	total: 725ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 206558.2168132	total: 1ms	remaining: 999ms
# 500:	learn: 9144.7067525	total: 372ms	remaining: 371ms
# 999:	learn: 6368.2209314	total: 740ms	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 234727.0516516	total: 1.54ms	remaining: 4.63s
# 500:	learn: 129229.1893855	total: 341ms	remaining: 1.7s
# 1000:	learn: 103813.2392067	total: 700ms	remaining: 1.4s
# 1500:	learn: 86294.3585803	total: 1.08s	remaining: 1.08s
# 2000:	learn: 74742.0512552	total: 1.44s	remaining: 718ms
# 2500:	learn: 65301.5411500	total: 1.8s	remaining: 360ms
# 2999:	learn: 56231.1821719	total: 2.17s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.3s
# 0:	learn: 236367.5121378	total: 1.48ms	remaining: 4.44s
# 500:	learn: 139075.2827231	total: 338ms	remaining: 1.68s
# 1000:	learn: 104194.0553881	total: 703ms	remaining: 1.4s
# 1500:	learn: 89227.1062264	total: 1.05s	remaining: 1.05s
# 2000:	learn: 78281.4989113	total: 1.42s	remaining: 708ms
# 2500:	learn: 71942.6132619	total: 1.76s	remaining: 351ms
# 2999:	learn: 66411.4844217	total: 2.09s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 232046.8439766	total: 1.54ms	remaining: 4.62s
# 500:	learn: 62270.6257137	total: 373ms	remaining: 1.86s
# 1000:	learn: 42937.5332233	total: 762ms	remaining: 1.52s
# 1500:	learn: 31777.8823075	total: 1.13s	remaining: 1.13s
# 2000:	learn: 25025.7314622	total: 1.5s	remaining: 749ms
# 2500:	learn: 20386.1038373	total: 1.85s	remaining: 369ms
# 2999:	learn: 17650.0828915	total: 2.22s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.3s
# 0:	learn: 233739.9853485	total: 2.35ms	remaining: 7.06s
# 500:	learn: 67317.9864261	total: 375ms	remaining: 1.87s
# 1000:	learn: 42662.2637858	total: 738ms	remaining: 1.47s
# 1500:	learn: 29551.6988500	total: 1.11s	remaining: 1.11s
# 2000:	learn: 22691.3355051	total: 1.49s	remaining: 746ms
# 2500:	learn: 18446.5325173	total: 1.87s	remaining: 373ms
# 2999:	learn: 15619.0665056	total: 2.25s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.4s
# 0:	learn: 228874.2171645	total: 1.48ms	remaining: 4.43s
# 500:	learn: 33800.5466128	total: 368ms	remaining: 1.84s
# 1000:	learn: 21347.4297550	total: 724ms	remaining: 1.45s
# 1500:	learn: 14064.0935237	total: 1.1s	remaining: 1.09s
# 2000:	learn: 10447.9700449	total: 1.47s	remaining: 731ms
# 2500:	learn: 7865.6543107	total: 1.84s	remaining: 367ms
# 2999:	learn: 6388.7731143	total: 2.23s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.4s
# 0:	learn: 230474.1830885	total: 972us	remaining: 2.92s
# 500:	learn: 43711.1189738	total: 374ms	remaining: 1.86s
# 1000:	learn: 23190.4740377	total: 766ms	remaining: 1.53s
# 1500:	learn: 14382.0295983	total: 1.15s	remaining: 1.15s
# 2000:	learn: 10637.8990945	total: 1.54s	remaining: 768ms
# 2500:	learn: 8113.1677843	total: 1.93s	remaining: 386ms
# 2999:	learn: 6551.3471930	total: 2.3s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.4s
# 0:	learn: 210494.5331848	total: 1.45ms	remaining: 4.36s
# 500:	learn: 4883.9365470	total: 365ms	remaining: 1.82s
# 1000:	learn: 1977.9018343	total: 756ms	remaining: 1.51s
# 1500:	learn: 924.3153807	total: 1.1s	remaining: 1.1s
# 2000:	learn: 743.0015697	total: 1.47s	remaining: 735ms
# 2500:	learn: 690.3859362	total: 1.81s	remaining: 361ms
# 2999:	learn: 235.9133694	total: 2.2s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.3s
# 0:	learn: 206558.2168132	total: 882us	remaining: 2.65s
# 500:	learn: 9144.7067525	total: 412ms	remaining: 2.05s
# 1000:	learn: 6368.2048373	total: 812ms	remaining: 1.62s
# 1500:	learn: 3992.4817329	total: 1.19s	remaining: 1.19s
# 2000:	learn: 2313.2587739	total: 1.56s	remaining: 781ms
# 2500:	learn: 1677.3186205	total: 1.94s	remaining: 387ms
# 2999:	learn: 629.1363825	total: 2.34s	remaining: 0us
# [CV] END border_count=128, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.5s
# 0:	learn: 234426.0611716	total: 1.82ms	remaining: 1.82s
# 500:	learn: 70788.9030851	total: 771ms	remaining: 768ms
# 999:	learn: 30784.2642324	total: 1.65s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 236100.1849756	total: 1.94ms	remaining: 1.94s
# 500:	learn: 72543.6417897	total: 743ms	remaining: 740ms
# 999:	learn: 29774.8572412	total: 1.62s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 230505.1468297	total: 1.86ms	remaining: 1.86s
# 500:	learn: 6813.8663842	total: 873ms	remaining: 869ms
# 999:	learn: 1314.4627624	total: 1.74s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 232399.0671870	total: 2.01ms	remaining: 2s
# 500:	learn: 5372.6304514	total: 876ms	remaining: 872ms
# 999:	learn: 1369.1039536	total: 1.75s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 225808.5688894	total: 1.59ms	remaining: 1.59s
# 500:	learn: 695.8414586	total: 870ms	remaining: 866ms
# 999:	learn: 115.9345926	total: 1.77s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 227792.3467653	total: 3.52ms	remaining: 3.52s
# 500:	learn: 735.9687143	total: 880ms	remaining: 876ms
# 999:	learn: 43.8112130	total: 1.78s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 193749.7079636	total: 1.86ms	remaining: 1.85s
# 500:	learn: 11.0659665	total: 885ms	remaining: 881ms
# 999:	learn: 0.6916227	total: 1.78s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 198046.1548663	total: 2.07ms	remaining: 2.07s
# 500:	learn: 0.0000118	total: 896ms	remaining: 893ms
# 999:	learn: 0.0000000	total: 1.8s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 234426.0611716	total: 2.02ms	remaining: 6.04s
# 500:	learn: 70788.9030851	total: 796ms	remaining: 3.97s
# 1000:	learn: 30665.7375889	total: 1.7s	remaining: 3.39s
# 1500:	learn: 14044.5841570	total: 2.58s	remaining: 2.58s
# 2000:	learn: 7492.1993892	total: 3.46s	remaining: 1.73s
# 2500:	learn: 4240.2633845	total: 4.34s	remaining: 866ms
# 2999:	learn: 2656.2177893	total: 5.21s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 236100.1849756	total: 1.87ms	remaining: 5.61s
# 500:	learn: 72543.6417897	total: 773ms	remaining: 3.85s
# 1000:	learn: 29739.3483044	total: 1.64s	remaining: 3.28s
# 1500:	learn: 14812.7714906	total: 2.48s	remaining: 2.48s
# 2000:	learn: 8646.4876641	total: 3.34s	remaining: 1.67s
# 2500:	learn: 5320.7636032	total: 4.2s	remaining: 838ms
# 2999:	learn: 3616.7098233	total: 5.06s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.3s
# 0:	learn: 230505.1468297	total: 2.11ms	remaining: 6.32s
# 500:	learn: 6813.8663842	total: 841ms	remaining: 4.19s
# 1000:	learn: 1313.9771703	total: 1.73s	remaining: 3.46s
# 1500:	learn: 353.5339104	total: 2.63s	remaining: 2.62s
# 2000:	learn: 179.9795527	total: 3.54s	remaining: 1.77s
# 2500:	learn: 99.6971369	total: 4.43s	remaining: 884ms
# 2999:	learn: 71.7574444	total: 5.32s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 232399.0671870	total: 2.04ms	remaining: 6.12s
# 500:	learn: 5372.6304514	total: 880ms	remaining: 4.39s
# 1000:	learn: 1368.9932431	total: 1.76s	remaining: 3.52s
# 1500:	learn: 519.5370872	total: 2.65s	remaining: 2.64s
# 2000:	learn: 234.4267655	total: 3.55s	remaining: 1.77s
# 2500:	learn: 81.2389454	total: 4.44s	remaining: 885ms
# 2999:	learn: 27.2689553	total: 5.33s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 225808.5688894	total: 1.84ms	remaining: 5.52s
# 500:	learn: 695.8414586	total: 897ms	remaining: 4.48s
# 1000:	learn: 115.7688126	total: 1.78s	remaining: 3.55s
# 1500:	learn: 71.9019899	total: 2.67s	remaining: 2.67s
# 2000:	learn: 32.3653830	total: 3.55s	remaining: 1.77s
# 2500:	learn: 4.1099649	total: 4.43s	remaining: 885ms
# 2999:	learn: 0.7923680	total: 5.33s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 227792.3467653	total: 2.12ms	remaining: 6.36s
# 500:	learn: 735.9687143	total: 828ms	remaining: 4.13s
# 1000:	learn: 43.8093087	total: 1.67s	remaining: 3.34s
# 1500:	learn: 3.4256129	total: 2.52s	remaining: 2.52s
# 2000:	learn: 0.0036394	total: 3.39s	remaining: 1.69s
# 2500:	learn: 0.0000001	total: 4.23s	remaining: 845ms
# 2999:	learn: 0.0000000	total: 5.02s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.2s
# 0:	learn: 193749.7079636	total: 1.92ms	remaining: 5.76s
# 500:	learn: 11.0659665	total: 851ms	remaining: 4.25s
# 1000:	learn: 0.6916227	total: 1.69s	remaining: 3.37s
# 1500:	learn: 0.0864281	total: 2.53s	remaining: 2.53s
# 2000:	learn: 0.0013505	total: 3.39s	remaining: 1.69s
# 2500:	learn: 0.0000844	total: 4.24s	remaining: 846ms
# 2999:	learn: 0.0000053	total: 5.1s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.4s
# 0:	learn: 198046.1548663	total: 1.96ms	remaining: 5.87s
# 500:	learn: 0.0000118	total: 831ms	remaining: 4.15s
# 1000:	learn: 0.0000000	total: 1.68s	remaining: 3.35s
# 1500:	learn: 0.0000001	total: 2.51s	remaining: 2.51s
# 2000:	learn: 0.0000001	total: 3.34s	remaining: 1.67s
# 2500:	learn: 0.0000001	total: 4.18s	remaining: 833ms
# 2999:	learn: 0.0000001	total: 5.01s	remaining: 0us
# [CV] END border_count=128, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.3s
# 0:	learn: 234980.6457165	total: 1.46ms	remaining: 1.46s
# 500:	learn: 156543.7126245	total: 206ms	remaining: 205ms
# 999:	learn: 138886.5357919	total: 421ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 236546.1766470	total: 608us	remaining: 608ms
# 500:	learn: 165758.4236714	total: 207ms	remaining: 206ms
# 999:	learn: 145306.9944825	total: 396ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 233321.3271814	total: 619us	remaining: 619ms
# 500:	learn: 112798.9256608	total: 195ms	remaining: 194ms
# 999:	learn: 93426.0281064	total: 390ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 234637.4229725	total: 1.28ms	remaining: 1.28s
# 500:	learn: 115952.5678346	total: 205ms	remaining: 204ms
# 999:	learn: 97067.3468910	total: 391ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 231398.5012709	total: 519us	remaining: 519ms
# 500:	learn: 96576.7339061	total: 218ms	remaining: 217ms
# 999:	learn: 73895.0048889	total: 455ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 232269.0583364	total: 1.93ms	remaining: 1.92s
# 500:	learn: 98579.5930709	total: 209ms	remaining: 208ms
# 999:	learn: 81584.2728250	total: 399ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 220650.8296450	total: 624us	remaining: 624ms
# 500:	learn: 38922.8455281	total: 217ms	remaining: 216ms
# 999:	learn: 25660.4924355	total: 438ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 215614.2123884	total: 636us	remaining: 636ms
# 500:	learn: 49972.2205899	total: 184ms	remaining: 183ms
# 999:	learn: 34641.3402509	total: 385ms	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 234980.6457165	total: 605us	remaining: 1.81s
# 500:	learn: 156543.7126245	total: 188ms	remaining: 940ms
# 1000:	learn: 138874.8134299	total: 406ms	remaining: 811ms
# 1500:	learn: 127557.3258225	total: 603ms	remaining: 602ms
# 2000:	learn: 119407.9158077	total: 790ms	remaining: 395ms
# 2500:	learn: 113314.4481111	total: 989ms	remaining: 197ms
# 2999:	learn: 109633.2404054	total: 1.19s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 236546.1766470	total: 656us	remaining: 1.97s
# 500:	learn: 165758.4236714	total: 209ms	remaining: 1.04s
# 1000:	learn: 145290.2715429	total: 395ms	remaining: 789ms
# 1500:	learn: 131859.6375413	total: 555ms	remaining: 555ms
# 2000:	learn: 125413.9603137	total: 744ms	remaining: 372ms
# 2500:	learn: 119788.1002979	total: 940ms	remaining: 187ms
# 2999:	learn: 115546.5826523	total: 1.11s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 233321.3271814	total: 1.33ms	remaining: 3.98s
# 500:	learn: 112798.9256608	total: 202ms	remaining: 1.01s
# 1000:	learn: 93424.0755650	total: 416ms	remaining: 830ms
# 1500:	learn: 82836.2760323	total: 620ms	remaining: 620ms
# 2000:	learn: 73443.0455119	total: 814ms	remaining: 406ms
# 2500:	learn: 66143.7998674	total: 1.01s	remaining: 201ms
# 2999:	learn: 62534.4963403	total: 1.2s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 234637.4229725	total: 533us	remaining: 1.6s
# 500:	learn: 115952.5678346	total: 164ms	remaining: 819ms
# 1000:	learn: 97062.2272437	total: 372ms	remaining: 744ms
# 1500:	learn: 88504.8930129	total: 594ms	remaining: 593ms
# 2000:	learn: 82895.2853462	total: 806ms	remaining: 403ms
# 2500:	learn: 78965.6598648	total: 1.01s	remaining: 201ms
# 2999:	learn: 73997.2595395	total: 1.18s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 231398.5012709	total: 662us	remaining: 1.99s
# 500:	learn: 96576.7339061	total: 214ms	remaining: 1.07s
# 1000:	learn: 73885.3383860	total: 440ms	remaining: 878ms
# 1500:	learn: 59795.0046239	total: 645ms	remaining: 644ms
# 2000:	learn: 54908.9644971	total: 859ms	remaining: 429ms
# 2500:	learn: 50443.9087255	total: 1.08s	remaining: 215ms
# 2999:	learn: 48168.2500310	total: 1.27s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 232269.0583364	total: 506us	remaining: 1.52s
# 500:	learn: 98579.5930709	total: 201ms	remaining: 1s
# 1000:	learn: 81577.5704343	total: 396ms	remaining: 790ms
# 1500:	learn: 70081.2499778	total: 571ms	remaining: 571ms
# 2000:	learn: 61185.2548301	total: 764ms	remaining: 381ms
# 2500:	learn: 56353.8781803	total: 973ms	remaining: 194ms
# 2999:	learn: 50376.8747036	total: 1.18s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 220650.8296450	total: 1.28ms	remaining: 3.85s
# 500:	learn: 38922.8455281	total: 235ms	remaining: 1.17s
# 1000:	learn: 25658.9697122	total: 449ms	remaining: 897ms
# 1500:	learn: 21902.3637973	total: 658ms	remaining: 657ms
# 2000:	learn: 18058.8120617	total: 887ms	remaining: 443ms
# 2500:	learn: 16945.1728703	total: 1.11s	remaining: 221ms
# 2999:	learn: 15146.9138700	total: 1.32s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 215614.2123884	total: 575us	remaining: 1.73s
# 500:	learn: 49972.2205899	total: 195ms	remaining: 973ms
# 1000:	learn: 34637.1596539	total: 424ms	remaining: 847ms
# 1500:	learn: 28270.3504258	total: 628ms	remaining: 627ms
# 2000:	learn: 20067.8817414	total: 856ms	remaining: 428ms
# 2500:	learn: 17609.0640263	total: 1.08s	remaining: 216ms
# 2999:	learn: 15665.5050693	total: 1.31s	remaining: 0us
# [CV] END border_count=254, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 234497.1559488	total: 790us	remaining: 790ms
# 500:	learn: 128633.0505773	total: 313ms	remaining: 311ms
# 999:	learn: 104836.2065292	total: 633ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 236367.5121378	total: 885us	remaining: 884ms
# 500:	learn: 136681.7503122	total: 299ms	remaining: 298ms
# 999:	learn: 104556.2311145	total: 613ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.6s
# 0:	learn: 230921.2189591	total: 1.6ms	remaining: 1.6s
# 500:	learn: 62638.3892903	total: 334ms	remaining: 333ms
# 999:	learn: 37663.8241539	total: 672ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 233739.9853485	total: 1.41ms	remaining: 1.41s
# 500:	learn: 63716.4825715	total: 327ms	remaining: 326ms
# 999:	learn: 46686.6542323	total: 642ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 226839.3556358	total: 782us	remaining: 782ms
# 500:	learn: 40974.1239887	total: 329ms	remaining: 327ms
# 999:	learn: 23178.7498052	total: 658ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 230474.1830885	total: 823us	remaining: 822ms
# 500:	learn: 44490.8218640	total: 347ms	remaining: 346ms
# 999:	learn: 26979.4282523	total: 675ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 201012.8628309	total: 791us	remaining: 791ms
# 500:	learn: 8297.9627463	total: 346ms	remaining: 344ms
# 999:	learn: 4986.9134146	total: 700ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 206558.2168132	total: 810us	remaining: 810ms
# 500:	learn: 8733.9801973	total: 351ms	remaining: 350ms
# 999:	learn: 3265.4456891	total: 707ms	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 234497.1559488	total: 715us	remaining: 2.15s
# 500:	learn: 128633.0505773	total: 311ms	remaining: 1.55s
# 1000:	learn: 104800.6526937	total: 635ms	remaining: 1.27s
# 1500:	learn: 85792.4980975	total: 965ms	remaining: 964ms
# 2000:	learn: 75648.7240907	total: 1.28s	remaining: 641ms
# 2500:	learn: 66657.3264402	total: 1.6s	remaining: 320ms
# 2999:	learn: 60844.6844459	total: 1.91s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.0s
# 0:	learn: 236367.5121378	total: 850us	remaining: 2.55s
# 500:	learn: 136681.7503122	total: 329ms	remaining: 1.64s
# 1000:	learn: 104538.3796746	total: 637ms	remaining: 1.27s
# 1500:	learn: 87481.5669835	total: 970ms	remaining: 969ms
# 2000:	learn: 76383.0336493	total: 1.31s	remaining: 657ms
# 2500:	learn: 68914.6445527	total: 1.63s	remaining: 326ms
# 2999:	learn: 63309.1379505	total: 1.96s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 230921.2189591	total: 705us	remaining: 2.12s
# 500:	learn: 62638.3892903	total: 341ms	remaining: 1.7s
# 1000:	learn: 37662.9562870	total: 671ms	remaining: 1.34s
# 1500:	learn: 28075.6649436	total: 995ms	remaining: 994ms
# 2000:	learn: 22060.0139946	total: 1.33s	remaining: 663ms
# 2500:	learn: 17398.3253116	total: 1.67s	remaining: 334ms
# 2999:	learn: 14510.7970084	total: 2s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 233739.9853485	total: 872us	remaining: 2.62s
# 500:	learn: 63716.4825715	total: 329ms	remaining: 1.64s
# 1000:	learn: 46671.5719216	total: 673ms	remaining: 1.34s
# 1500:	learn: 34148.6015311	total: 998ms	remaining: 997ms
# 2000:	learn: 25270.0909380	total: 1.33s	remaining: 663ms
# 2500:	learn: 20123.3134715	total: 1.65s	remaining: 330ms
# 2999:	learn: 16545.0116466	total: 1.99s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 226839.3556358	total: 768us	remaining: 2.3s
# 500:	learn: 40974.1239887	total: 351ms	remaining: 1.75s
# 1000:	learn: 23176.3088336	total: 680ms	remaining: 1.36s
# 1500:	learn: 15644.3019877	total: 1.03s	remaining: 1.02s
# 2000:	learn: 11518.1090173	total: 1.39s	remaining: 694ms
# 2500:	learn: 9151.0660583	total: 1.74s	remaining: 348ms
# 2999:	learn: 6789.8362514	total: 2.11s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 230474.1830885	total: 1.02ms	remaining: 3.05s
# 500:	learn: 44490.8218640	total: 353ms	remaining: 1.76s
# 1000:	learn: 26959.3869177	total: 672ms	remaining: 1.34s
# 1500:	learn: 16228.7369932	total: 997ms	remaining: 996ms
# 2000:	learn: 11159.1646167	total: 1.32s	remaining: 660ms
# 2500:	learn: 8867.3170295	total: 1.68s	remaining: 335ms
# 2999:	learn: 7531.8100246	total: 2.02s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 201012.8628309	total: 792us	remaining: 2.38s
# 500:	learn: 8297.9627463	total: 349ms	remaining: 1.74s
# 1000:	learn: 4986.9055829	total: 711ms	remaining: 1.42s
# 1500:	learn: 2043.2224795	total: 1.06s	remaining: 1.06s
# 2000:	learn: 1720.8304691	total: 1.42s	remaining: 710ms
# 2500:	learn: 1164.8459009	total: 1.79s	remaining: 357ms
# 2999:	learn: 645.2709337	total: 2.12s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 206558.2168132	total: 935us	remaining: 2.81s
# 500:	learn: 8733.9801973	total: 348ms	remaining: 1.74s
# 1000:	learn: 3227.9448660	total: 697ms	remaining: 1.39s
# 1500:	learn: 1471.7467726	total: 1.08s	remaining: 1.08s
# 2000:	learn: 678.7463158	total: 1.44s	remaining: 718ms
# 2500:	learn: 553.8005994	total: 1.77s	remaining: 353ms
# 2999:	learn: 242.5248769	total: 2.13s	remaining: 0us
# [CV] END border_count=254, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 234237.8199811	total: 1.99ms	remaining: 1.99s
# 500:	learn: 73029.1227831	total: 733ms	remaining: 730ms
# 999:	learn: 34368.1285891	total: 1.6s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 236100.1849756	total: 2.1ms	remaining: 2.1s
# 500:	learn: 71588.6590111	total: 737ms	remaining: 734ms
# 999:	learn: 29155.4579280	total: 1.58s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 229693.8589876	total: 1.81ms	remaining: 1.81s
# 500:	learn: 3041.8271885	total: 854ms	remaining: 850ms
# 999:	learn: 619.2516799	total: 1.72s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 232399.0671870	total: 1.89ms	remaining: 1.89s
# 500:	learn: 3555.5419955	total: 848ms	remaining: 845ms
# 999:	learn: 802.3824505	total: 1.71s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 224369.0091385	total: 1.72ms	remaining: 1.72s
# 500:	learn: 369.1086882	total: 867ms	remaining: 863ms
# 999:	learn: 74.1174291	total: 1.74s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 227792.3467653	total: 1.94ms	remaining: 1.94s
# 500:	learn: 1616.3259884	total: 844ms	remaining: 841ms
# 999:	learn: 241.7130440	total: 1.72s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 186556.0951317	total: 1.94ms	remaining: 1.94s
# 500:	learn: 3.7470929	total: 896ms	remaining: 893ms
# 999:	learn: 1.8525107	total: 1.77s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 198046.1548663	total: 1.95ms	remaining: 1.94s
# 500:	learn: 0.0000000	total: 865ms	remaining: 861ms
# 999:	learn: 0.0000000	total: 1.74s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 234237.8199811	total: 1.92ms	remaining: 5.75s
# 500:	learn: 73029.1227831	total: 770ms	remaining: 3.84s
# 1000:	learn: 34269.6010747	total: 1.66s	remaining: 3.32s
# 1500:	learn: 17180.8625628	total: 2.51s	remaining: 2.51s
# 2000:	learn: 8878.6897024	total: 3.38s	remaining: 1.69s
# 2500:	learn: 4549.1257612	total: 4.25s	remaining: 848ms
# 2999:	learn: 3016.6646984	total: 5.15s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.4s
# 0:	learn: 236100.1849756	total: 1.91ms	remaining: 5.72s
# 500:	learn: 71588.6590111	total: 742ms	remaining: 3.7s
# 1000:	learn: 29105.7270906	total: 1.61s	remaining: 3.21s
# 1500:	learn: 14126.4960013	total: 2.46s	remaining: 2.46s
# 2000:	learn: 7729.8546571	total: 3.3s	remaining: 1.65s
# 2500:	learn: 4607.2257052	total: 4.17s	remaining: 832ms
# 2999:	learn: 3167.9463367	total: 5.02s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.3s
# 0:	learn: 229693.8589876	total: 1.93ms	remaining: 5.8s
# 500:	learn: 3041.8271885	total: 851ms	remaining: 4.25s
# 1000:	learn: 619.1759408	total: 1.76s	remaining: 3.52s
# 1500:	learn: 249.1129639	total: 2.67s	remaining: 2.66s
# 2000:	learn: 125.5152678	total: 3.55s	remaining: 1.77s
# 2500:	learn: 80.7688046	total: 4.47s	remaining: 892ms
# 2999:	learn: 59.6051994	total: 5.36s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 232399.0671870	total: 1.98ms	remaining: 5.95s
# 500:	learn: 3555.5419955	total: 842ms	remaining: 4.2s
# 1000:	learn: 801.9438702	total: 1.75s	remaining: 3.5s
# 1500:	learn: 292.6635660	total: 2.62s	remaining: 2.61s
# 2000:	learn: 119.6700246	total: 3.46s	remaining: 1.73s
# 2500:	learn: 56.8944100	total: 4.36s	remaining: 869ms
# 2999:	learn: 18.2691155	total: 5.22s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 224369.0091385	total: 1.87ms	remaining: 5.62s
# 500:	learn: 369.1086882	total: 861ms	remaining: 4.29s
# 1000:	learn: 74.1159002	total: 1.74s	remaining: 3.48s
# 1500:	learn: 27.3098840	total: 2.62s	remaining: 2.62s
# 2000:	learn: 6.7066788	total: 3.52s	remaining: 1.76s
# 2500:	learn: 1.8927183	total: 4.4s	remaining: 879ms
# 2999:	learn: 1.5329950	total: 5.14s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.4s
# 0:	learn: 227792.3467653	total: 1.92ms	remaining: 5.76s
# 500:	learn: 1616.3259884	total: 848ms	remaining: 4.23s
# 1000:	learn: 241.7129271	total: 1.73s	remaining: 3.46s
# 1500:	learn: 24.4722451	total: 2.6s	remaining: 2.6s
# 2000:	learn: 0.1763953	total: 3.51s	remaining: 1.75s
# 2500:	learn: 0.0000090	total: 4.41s	remaining: 880ms
# 2999:	learn: 0.0000011	total: 5.25s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 186556.0951317	total: 2.14ms	remaining: 6.41s
# 500:	learn: 3.7470929	total: 882ms	remaining: 4.4s
# 1000:	learn: 1.8525083	total: 1.79s	remaining: 3.58s
# 1500:	learn: 0.1157816	total: 2.68s	remaining: 2.67s
# 2000:	learn: 0.0018092	total: 3.57s	remaining: 1.78s
# 2500:	learn: 0.0004523	total: 4.45s	remaining: 888ms
# 2999:	learn: 0.0000566	total: 5.36s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 198046.1548663	total: 1.96ms	remaining: 5.87s
# 500:	learn: 0.0000000	total: 882ms	remaining: 4.4s
# 1000:	learn: 0.0000000	total: 1.77s	remaining: 3.54s
# 1500:	learn: 0.0000000	total: 2.62s	remaining: 2.62s
# 2000:	learn: 0.0000001	total: 3.48s	remaining: 1.74s
# 2500:	learn: 0.0000001	total: 4.34s	remaining: 866ms
# 2999:	learn: 0.0000000	total: 5.24s	remaining: 0us
# [CV] END border_count=254, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 234980.6457165	total: 2.03ms	remaining: 2.02s
# 500:	learn: 156543.7126245	total: 194ms	remaining: 194ms
# 999:	learn: 138886.5357919	total: 373ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 236546.1766470	total: 599us	remaining: 599ms
# 500:	learn: 165758.4236714	total: 217ms	remaining: 216ms
# 999:	learn: 145306.9944825	total: 411ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 233321.3271814	total: 559us	remaining: 559ms
# 500:	learn: 112798.9256608	total: 215ms	remaining: 214ms
# 999:	learn: 93426.0281064	total: 437ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 234637.4229725	total: 533us	remaining: 533ms
# 500:	learn: 115952.5678346	total: 184ms	remaining: 183ms
# 999:	learn: 97067.3468910	total: 386ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 231398.5012709	total: 1.07ms	remaining: 1.07s
# 500:	learn: 96576.7339061	total: 206ms	remaining: 205ms
# 999:	learn: 73895.0048889	total: 416ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 232269.0583364	total: 485us	remaining: 485ms
# 500:	learn: 98579.5930709	total: 190ms	remaining: 189ms
# 999:	learn: 81584.2728250	total: 398ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 220650.8296450	total: 533us	remaining: 533ms
# 500:	learn: 38922.8455281	total: 216ms	remaining: 215ms
# 999:	learn: 25660.4924355	total: 407ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.4s
# 0:	learn: 215614.2123884	total: 512us	remaining: 512ms
# 500:	learn: 49972.2205899	total: 229ms	remaining: 228ms
# 999:	learn: 34641.3402509	total: 445ms	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.5s
# 0:	learn: 234980.6457165	total: 1.23ms	remaining: 3.7s
# 500:	learn: 156543.7126245	total: 195ms	remaining: 974ms
# 1000:	learn: 138874.8134299	total: 408ms	remaining: 815ms
# 1500:	learn: 127557.3258225	total: 602ms	remaining: 602ms
# 2000:	learn: 119407.9158077	total: 788ms	remaining: 394ms
# 2500:	learn: 113314.4481111	total: 981ms	remaining: 196ms
# 2999:	learn: 109633.2404054	total: 1.18s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 236546.1766470	total: 562us	remaining: 1.69s
# 500:	learn: 165758.4236714	total: 211ms	remaining: 1.05s
# 1000:	learn: 145290.2715429	total: 408ms	remaining: 815ms
# 1500:	learn: 131859.6375413	total: 614ms	remaining: 613ms
# 2000:	learn: 125413.9603137	total: 788ms	remaining: 394ms
# 2500:	learn: 119788.1002979	total: 975ms	remaining: 194ms
# 2999:	learn: 115546.5826523	total: 1.15s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 233321.3271814	total: 1.11ms	remaining: 3.34s
# 500:	learn: 112798.9256608	total: 185ms	remaining: 925ms
# 1000:	learn: 93424.0755650	total: 392ms	remaining: 784ms
# 1500:	learn: 82836.2760323	total: 559ms	remaining: 558ms
# 2000:	learn: 73443.0455119	total: 730ms	remaining: 365ms
# 2500:	learn: 66143.7998674	total: 919ms	remaining: 183ms
# 2999:	learn: 62534.4963403	total: 1.11s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.2s
# 0:	learn: 234637.4229725	total: 1.24ms	remaining: 3.71s
# 500:	learn: 115952.5678346	total: 180ms	remaining: 900ms
# 1000:	learn: 97062.2272437	total: 382ms	remaining: 763ms
# 1500:	learn: 88504.8930129	total: 591ms	remaining: 590ms
# 2000:	learn: 82895.2853462	total: 791ms	remaining: 395ms
# 2500:	learn: 78965.6598648	total: 1.01s	remaining: 202ms
# 2999:	learn: 73997.2595395	total: 1.21s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 231398.5012709	total: 1.26ms	remaining: 3.77s
# 500:	learn: 96576.7339061	total: 191ms	remaining: 955ms
# 1000:	learn: 73885.3383860	total: 418ms	remaining: 835ms
# 1500:	learn: 59795.0046239	total: 638ms	remaining: 637ms
# 2000:	learn: 54908.9644971	total: 848ms	remaining: 423ms
# 2500:	learn: 50443.9087255	total: 1.06s	remaining: 211ms
# 2999:	learn: 48168.2500310	total: 1.27s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 232269.0583364	total: 516us	remaining: 1.55s
# 500:	learn: 98579.5930709	total: 219ms	remaining: 1.09s
# 1000:	learn: 81577.5704343	total: 420ms	remaining: 839ms
# 1500:	learn: 70081.2499778	total: 612ms	remaining: 611ms
# 2000:	learn: 61185.2548301	total: 809ms	remaining: 404ms
# 2500:	learn: 56353.8781803	total: 1.01s	remaining: 201ms
# 2999:	learn: 50376.8747036	total: 1.21s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.3s
# 0:	learn: 220650.8296450	total: 561us	remaining: 1.68s
# 500:	learn: 38922.8455281	total: 194ms	remaining: 970ms
# 1000:	learn: 25658.9697122	total: 419ms	remaining: 837ms
# 1500:	learn: 21902.3637973	total: 647ms	remaining: 647ms
# 2000:	learn: 18058.8120617	total: 872ms	remaining: 435ms
# 2500:	learn: 16945.1728703	total: 1.07s	remaining: 214ms
# 2999:	learn: 15146.9138700	total: 1.3s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 215614.2123884	total: 529us	remaining: 1.59s
# 500:	learn: 49972.2205899	total: 228ms	remaining: 1.14s
# 1000:	learn: 34637.1596539	total: 447ms	remaining: 892ms
# 1500:	learn: 28270.3504258	total: 664ms	remaining: 663ms
# 2000:	learn: 20067.8817414	total: 891ms	remaining: 445ms
# 2500:	learn: 17609.0640263	total: 1.11s	remaining: 222ms
# 2999:	learn: 15665.5050693	total: 1.33s	remaining: 0us
# [CV] END border_count=500, depth=4, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.4s
# 0:	learn: 234497.1559488	total: 1.27ms	remaining: 1.27s
# 500:	learn: 128633.0505773	total: 313ms	remaining: 312ms
# 999:	learn: 104836.2065292	total: 656ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 236367.5121378	total: 802us	remaining: 802ms
# 500:	learn: 136681.7503122	total: 320ms	remaining: 318ms
# 999:	learn: 104556.2311145	total: 642ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 230921.2189591	total: 789us	remaining: 789ms
# 500:	learn: 62638.3892903	total: 328ms	remaining: 326ms
# 999:	learn: 37663.8241539	total: 670ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 233739.9853485	total: 719us	remaining: 719ms
# 500:	learn: 63716.4825715	total: 350ms	remaining: 348ms
# 999:	learn: 46686.6542323	total: 677ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 226839.3556358	total: 744us	remaining: 744ms
# 500:	learn: 40974.1239887	total: 330ms	remaining: 328ms
# 999:	learn: 23178.7498052	total: 671ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 230474.1830885	total: 947us	remaining: 947ms
# 500:	learn: 44490.8218640	total: 377ms	remaining: 375ms
# 999:	learn: 26979.4282523	total: 720ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 201012.8628309	total: 800us	remaining: 799ms
# 500:	learn: 8297.9627463	total: 368ms	remaining: 366ms
# 999:	learn: 4986.9134146	total: 741ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.8s
# 0:	learn: 206558.2168132	total: 845us	remaining: 844ms
# 500:	learn: 8733.9801973	total: 350ms	remaining: 349ms
# 999:	learn: 3265.4456891	total: 711ms	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   0.7s
# 0:	learn: 234497.1559488	total: 773us	remaining: 2.32s
# 500:	learn: 128633.0505773	total: 321ms	remaining: 1.6s
# 1000:	learn: 104800.6526937	total: 648ms	remaining: 1.29s
# 1500:	learn: 85792.4980975	total: 971ms	remaining: 970ms
# 2000:	learn: 75648.7240907	total: 1.32s	remaining: 658ms
# 2500:	learn: 66657.3264402	total: 1.64s	remaining: 327ms
# 2999:	learn: 60844.6844459	total: 1.96s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 236367.5121378	total: 881us	remaining: 2.64s
# 500:	learn: 136681.7503122	total: 330ms	remaining: 1.64s
# 1000:	learn: 104538.3796746	total: 671ms	remaining: 1.34s
# 1500:	learn: 87481.5669835	total: 986ms	remaining: 985ms
# 2000:	learn: 76383.0336493	total: 1.3s	remaining: 651ms
# 2500:	learn: 68914.6445527	total: 1.62s	remaining: 324ms
# 2999:	learn: 63309.1379505	total: 1.95s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 230921.2189591	total: 740us	remaining: 2.22s
# 500:	learn: 62638.3892903	total: 356ms	remaining: 1.77s
# 1000:	learn: 37662.9562870	total: 703ms	remaining: 1.4s
# 1500:	learn: 28075.6649436	total: 1.04s	remaining: 1.03s
# 2000:	learn: 22060.0139946	total: 1.38s	remaining: 691ms
# 2500:	learn: 17398.3253116	total: 1.73s	remaining: 345ms
# 2999:	learn: 14510.7970084	total: 2.05s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 233739.9853485	total: 807us	remaining: 2.42s
# 500:	learn: 63716.4825715	total: 332ms	remaining: 1.66s
# 1000:	learn: 46671.5719216	total: 651ms	remaining: 1.3s
# 1500:	learn: 34148.6015311	total: 987ms	remaining: 986ms
# 2000:	learn: 25270.0909380	total: 1.32s	remaining: 662ms
# 2500:	learn: 20123.3134715	total: 1.68s	remaining: 335ms
# 2999:	learn: 16545.0116466	total: 2.02s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   2.1s
# 0:	learn: 226839.3556358	total: 736us	remaining: 2.21s
# 500:	learn: 40974.1239887	total: 336ms	remaining: 1.67s
# 1000:	learn: 23176.3088336	total: 691ms	remaining: 1.38s
# 1500:	learn: 15644.3019877	total: 1.04s	remaining: 1.04s
# 2000:	learn: 11518.1090173	total: 1.39s	remaining: 696ms
# 2500:	learn: 9151.0660583	total: 1.75s	remaining: 349ms
# 2999:	learn: 6789.8362514	total: 2.1s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 230474.1830885	total: 955us	remaining: 2.87s
# 500:	learn: 44490.8218640	total: 348ms	remaining: 1.74s
# 1000:	learn: 26959.3869177	total: 697ms	remaining: 1.39s
# 1500:	learn: 16228.7369932	total: 1.05s	remaining: 1.05s
# 2000:	learn: 11159.1646167	total: 1.4s	remaining: 700ms
# 2500:	learn: 8867.3170295	total: 1.76s	remaining: 351ms
# 2999:	learn: 7531.8100246	total: 2.1s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   2.2s
# 0:	learn: 201012.8628309	total: 624us	remaining: 1.87s
# 500:	learn: 8297.9627463	total: 359ms	remaining: 1.79s
# 1000:	learn: 4986.9055829	total: 718ms	remaining: 1.43s
# 1500:	learn: 2043.2224795	total: 1.09s	remaining: 1.09s
# 2000:	learn: 1720.8304691	total: 1.46s	remaining: 727ms
# 2500:	learn: 1164.8459009	total: 1.82s	remaining: 364ms
# 2999:	learn: 645.2709337	total: 2.19s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.3s
# 0:	learn: 206558.2168132	total: 985us	remaining: 2.96s
# 500:	learn: 8733.9801973	total: 349ms	remaining: 1.74s
# 1000:	learn: 3227.9448660	total: 702ms	remaining: 1.4s
# 1500:	learn: 1471.7467726	total: 1.06s	remaining: 1.06s
# 2000:	learn: 678.7463158	total: 1.42s	remaining: 709ms
# 2500:	learn: 553.8005994	total: 1.8s	remaining: 358ms
# 2999:	learn: 242.5248769	total: 2.17s	remaining: 0us
# [CV] END border_count=500, depth=6, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   2.3s
# 0:	learn: 234237.8199811	total: 1.88ms	remaining: 1.88s
# 500:	learn: 73029.1227831	total: 740ms	remaining: 737ms
# 999:	learn: 34368.1285891	total: 1.6s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 236100.1849756	total: 1.82ms	remaining: 1.82s
# 500:	learn: 71588.6590111	total: 752ms	remaining: 749ms
# 999:	learn: 29155.4579280	total: 1.61s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.01, subsample=1, verbose=500; total time=   1.7s
# 0:	learn: 229693.8589876	total: 1.79ms	remaining: 1.78s
# 500:	learn: 3041.8271885	total: 862ms	remaining: 858ms
# 999:	learn: 619.2516799	total: 1.75s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 232399.0671870	total: 1.93ms	remaining: 1.93s
# 500:	learn: 3555.5419955	total: 836ms	remaining: 833ms
# 999:	learn: 802.3824505	total: 1.71s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.05, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 224369.0091385	total: 1.75ms	remaining: 1.75s
# 500:	learn: 369.1086882	total: 899ms	remaining: 896ms
# 999:	learn: 74.1174291	total: 1.78s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 227792.3467653	total: 1.87ms	remaining: 1.87s
# 500:	learn: 1616.3259884	total: 864ms	remaining: 861ms
# 999:	learn: 241.7130440	total: 1.75s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.1, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 186556.0951317	total: 1.94ms	remaining: 1.94s
# 500:	learn: 3.7470929	total: 895ms	remaining: 891ms
# 999:	learn: 1.8525107	total: 1.79s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.9s
# 0:	learn: 198046.1548663	total: 1.99ms	remaining: 1.99s
# 500:	learn: 0.0000000	total: 899ms	remaining: 895ms
# 999:	learn: 0.0000000	total: 1.76s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=1000, learning_rate=0.5, subsample=1, verbose=500; total time=   1.8s
# 0:	learn: 234237.8199811	total: 1.8ms	remaining: 5.41s
# 500:	learn: 73029.1227831	total: 734ms	remaining: 3.66s
# 1000:	learn: 34269.6010747	total: 1.61s	remaining: 3.21s
# 1500:	learn: 17180.8625628	total: 2.46s	remaining: 2.45s
# 2000:	learn: 8878.6897024	total: 3.31s	remaining: 1.65s
# 2500:	learn: 4549.1257612	total: 4.19s	remaining: 836ms
# 2999:	learn: 3016.6646984	total: 5.06s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.3s
# 0:	learn: 236100.1849756	total: 1.98ms	remaining: 5.93s
# 500:	learn: 71588.6590111	total: 730ms	remaining: 3.64s
# 1000:	learn: 29105.7270906	total: 1.61s	remaining: 3.21s
# 1500:	learn: 14126.4960013	total: 2.46s	remaining: 2.45s
# 2000:	learn: 7729.8546571	total: 3.3s	remaining: 1.65s
# 2500:	learn: 4607.2257052	total: 4.17s	remaining: 832ms
# 2999:	learn: 3167.9463367	total: 5.01s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.01, subsample=1, verbose=500; total time=   5.2s
# 0:	learn: 229693.8589876	total: 1.92ms	remaining: 5.75s
# 500:	learn: 3041.8271885	total: 857ms	remaining: 4.27s
# 1000:	learn: 619.1759408	total: 1.77s	remaining: 3.54s
# 1500:	learn: 249.1129639	total: 2.66s	remaining: 2.66s
# 2000:	learn: 125.5152678	total: 3.54s	remaining: 1.77s
# 2500:	learn: 80.7688046	total: 4.46s	remaining: 889ms
# 2999:	learn: 59.6051994	total: 5.35s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 232399.0671870	total: 1.95ms	remaining: 5.86s
# 500:	learn: 3555.5419955	total: 842ms	remaining: 4.2s
# 1000:	learn: 801.9438702	total: 1.73s	remaining: 3.45s
# 1500:	learn: 292.6635660	total: 2.59s	remaining: 2.59s
# 2000:	learn: 119.6700246	total: 3.45s	remaining: 1.72s
# 2500:	learn: 56.8944100	total: 4.34s	remaining: 866ms
# 2999:	learn: 18.2691155	total: 5.2s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.05, subsample=1, verbose=500; total time=   5.4s
# 0:	learn: 224369.0091385	total: 2.09ms	remaining: 6.27s
# 500:	learn: 369.1086882	total: 878ms	remaining: 4.38s
# 1000:	learn: 74.1159002	total: 1.78s	remaining: 3.57s
# 1500:	learn: 27.3098840	total: 2.69s	remaining: 2.69s
# 2000:	learn: 6.7066788	total: 3.59s	remaining: 1.79s
# 2500:	learn: 1.8927183	total: 4.47s	remaining: 893ms
# 2999:	learn: 1.5329950	total: 5.23s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 227792.3467653	total: 2.13ms	remaining: 6.4s
# 500:	learn: 1616.3259884	total: 849ms	remaining: 4.24s
# 1000:	learn: 241.7129271	total: 1.73s	remaining: 3.46s
# 1500:	learn: 24.4722451	total: 2.6s	remaining: 2.6s
# 2000:	learn: 0.1763953	total: 3.48s	remaining: 1.74s
# 2500:	learn: 0.0000090	total: 4.36s	remaining: 870ms
# 2999:	learn: 0.0000011	total: 5.16s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.1, subsample=1, verbose=500; total time=   5.4s
# 0:	learn: 186556.0951317	total: 1.96ms	remaining: 5.88s
# 500:	learn: 3.7470929	total: 886ms	remaining: 4.42s
# 1000:	learn: 1.8525083	total: 1.79s	remaining: 3.57s
# 1500:	learn: 0.1157816	total: 2.67s	remaining: 2.67s
# 2000:	learn: 0.0018092	total: 3.55s	remaining: 1.77s
# 2500:	learn: 0.0004523	total: 4.46s	remaining: 890ms
# 2999:	learn: 0.0000566	total: 5.34s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.6s
# 0:	learn: 198046.1548663	total: 1.9ms	remaining: 5.7s
# 500:	learn: 0.0000000	total: 873ms	remaining: 4.36s
# 1000:	learn: 0.0000000	total: 1.77s	remaining: 3.53s
# 1500:	learn: 0.0000000	total: 2.63s	remaining: 2.62s
# 2000:	learn: 0.0000001	total: 3.5s	remaining: 1.75s
# 2500:	learn: 0.0000001	total: 4.39s	remaining: 875ms
# 2999:	learn: 0.0000000	total: 5.25s	remaining: 0us
# [CV] END border_count=500, depth=10, iterations=3000, learning_rate=0.5, subsample=1, verbose=500; total time=   5.5s
# 0:	learn: 235420.9682471	total: 2.04ms	remaining: 2.04s
# 500:	learn: 142444.2228527	total: 337ms	remaining: 336ms
# 999:	learn: 115871.0938545	total: 702ms	remaining: 0us
# test_error=  185303.90172908164  train_error=  128039.44412053228

# %%
# Best parameters
print("Best parameters found: ", grid_search.best_params_)

# Best estimator
best_model = grid_search.best_estimator_
print("Best model", best_model)
# Out:
# Best parameters found:  {'border_count': 254, 'depth': 6, 'iterations': 1000, 'learning_rate': 0.01, 'subsample': 1, 'verbose': 500}
# Best model <catboost.core.CatBoostRegressor object at 0x15ac88140>

# %%
# return ids and predicted outcome using model
def run_model(data, model):
    ids = data['id']
    data = data.drop(columns=['id'], axis=1)
    predicted_output = model.predict(data)
    return ids, predicted_output

# predict outcomes and save in file
def predict_output_and_save(ids_original_order, data, model):
    ids, car_valuations = run_model(data, model)
    car_valuations = car_valuations.astype(int)
    df = pd.DataFrame({
        'id': ids,
        'car_valuation': car_valuations
    })
    df.to_csv('/Users/vikash.yadav/Documents/data_science_hackathon/car_valuation_data.csv', index=False)

def predict_output(data, model):
    ids = data['id']
    data = prune_data(data)
    data.to_csv('/Users/vikash.yadav/Documents/data_science_hackathon/pruned_data.csv', index=False)
    print(data.columns)
    predict_output_and_save(ids, data, model)
